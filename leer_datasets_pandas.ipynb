# %%
import pandas as pd
data=pd.read_csv('/dat

#data=data2
#data=data.iloc[:30000,:]

cols=['x','y','theta']
n_reads=data.shape[1]-3
n_reads
etiquetas=[]
for i in range (n_reads):
    etiquetas.append('R'+str(i))

        
for lab in cols:
    etiquetas.append(lab)
data.columns=etiquetas

data.describe()
# Out:
#                 R0           R1           R2           R3           R4  \
# count  7350.000000  7350.000000  7350.000000  7350.000000  7350.000000
# mean      2.385386     2.342893     2.344072     2.335383     2.328176
# std       1.588932     1.567933     1.569502     1.571401     1.561027
# min       0.286000     0.279000     0.187000     0.146000     0.065000
# 25%       0.652000     0.652000     0.659000     0.659000     0.656250
# 50%       2.241000     2.228500     2.218000     2.212000     2.198000
# 75%       3.223750     3.172000     3.084750     2.953750     2.971000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#                 R5           R6           R7           R8           R9  ...  \
# count  7350.000000  7350.000000  7350.000000  7350.000000  7350.000000  ...
# mean      2.331458     2.328162     2.352624     2.372813     2.403029  ...
# std       1.548723     1.527291     1.517839     1.514220     1.525380  ...
# min       0.053000     0.100000     0.192000     0.352000     0.272000  ...
# 25%       0.669000     0.686250     0.720000     1.259500     1.493750  ...
# 50%       2.210000     2.215000     2.210000     2.214000     2.211000  ...
# 75%       2.957000     2.835750     2.954000     2.958000     2.951000  ...
# max      10.000000    10.000000    10.000000    10.000000    10.000000  ...
#
#               R956         R957         R958         R959         R960  \
# count  7350.000000  7350.000000  7350.000000  7350.000000  7350.000000
# mean      1.951030     1.947569     1.946296     1.945289     1.950312
# std       0.815931     0.820877     0.820162     0.816772     0.815713
# min       0.353000     0.335000     0.337000     0.267000     0.057000
# 25%       1.593000     1.592000     1.592000     1.590000     1.590000
# 50%       1.865000     1.867000     1.869000     1.870000     1.872000
# 75%       2.351750     2.357000     2.365750     2.369000     2.386000
# max       4.451000     4.452000     4.442000     4.457000     4.445000
#
#               R961         R962            x            y        theta
# count  7350.000000  7350.000000  7350.000000  7350.000000  7350.000000
# mean      1.953811     1.960473    -0.235033    -0.113422    -1.031705
# std       0.814553     0.813282     0.548696     0.427125     1.278315
# min       0.297000     0.255000    -0.911168    -0.632490    -2.763790
# 25%       1.590250     1.591000    -0.863748    -0.556406    -2.271052
# 50%       1.875000     1.878000    -0.086668    -0.104241    -0.886989
# 75%       2.400750     2.413000     0.326395     0.358740     0.022376
# max       4.458000     4.457000     0.427870     0.424781     0.925642
#
# [8 rows x 966 columns]

# %%
import os

# %%
# !ls
# Out:
#  A2.npy
#  aff_prop_class.joblib
#  aff_prop_class.joblib_01.npy
#  aff_prop_class.joblib_02.npy
#  aff_prop_class.joblib_03.npy
#  aff_prop_class.joblib_04.npy
#  aff_prop_class.joblib_2
#  A.npy
#  B2.npy
#  B.npy
#  ccvk.npy
#  ccxyth.npy
#  clickedpoint_to_topomap.py
#  dataset_candidatura_wr
#  demo_doc2_gazebo_world
#  Demo_Doct_2_sem
#  Dijkstra.py
#  est.npy
#  features_hokuyo2d.ipynb
#  generadorlecturasparaHMM_takeshi_Odom_Gazebo.py
#  generadorlecturasparaHMM_takeshi_Pose_Gazebo_lecs_obs.py
#  generadorlecturasparaHMM_takeshi_Pose_Gazebo.py
#  generadorlecturasparaHMM_takeshi_Pose_Gazebo_shitomasi_features.py
#  generadorlecturasparaHMM_takeshi_Pose.py
#  generadorlecturasparaHMM_takeshi.py
#  HMM_py3.pyc
#  HMMs
#  Hough_circle.py
#  imagesfromlistener
#  lec.npy
#  lecs_quant_Gazebo.py
#  leer_datasets_pandas.ipynb
#  lidar_circle_finder_Gazebo.py
# 'linear HMM'
#  listener.py
#  listener_py3.py
#  listener_py3_save_images.py
#  llec.npy
#  manual_ccxy.npy
#  navigate_AFF_PROP.py
#  NoisyOdom
#  obs.npy
#  pddata.csv
#  PI2.npy
#  PI.npy
#  potfields_aff.py
#  potfields_takeshi_clickedroute.py
#  potfields_takeshi_navroute_clickcumul.py
#  potfields_takeshi_navroute.py
#  potfields_takeshi_predefinedroute.py
#  potfields_takeshi.py
#  potfields_takeshi_topomap.py
#  potfields_viterbi_AFF_PROP.py
#  potfields_viterbi_KMEANS.py
#  potfields_viterbi.py
#  __pycache__
#  reads.ipynb
#  RealROBOT
#  shi_tomasi_features_node.py
#  shi_tomasi.py
#  smach_challenge_coll.py
#  smach_challenge.py
#  TakeshiHMM-DUAL-CAND-Copy1.ipynb
#  TakeshiHMM-DUAL-CAND.ipynb
#  TakeshiHMM-Gazebo-2.ipynb
#  TakeshiHMM-Gazebo-Clustering_AFF_PROP_OPTICS.ipynb
#  TakeshiHMM-Gazebo-Clustering_AFF_PROP_OPTICS.py
#  TakeshiHMM-Gazebo-FacingSAMEDIRECTION.ipynb
#  TakeshiHMM-Gazebo.ipynb
#  TakeshiHMM-Gazebo-NoiseODOM.ipynb
#  TakeshiHMM-Gazebo-NoiseODOM-REALROBOT-JUSTODOM.ipynb
#  TakeshiHMM-Gazebo-NOODOM.ipynb
#  TakeshiHMM-Gazebo-ODOM_CAND.ipynb
#  TakeshiHMM-Gazebo-Python2-IDEALODOM.ipynb
#  TakeshiHMM-Gazebo-Python2.ipynb
#  TakeshiHMM-Gazebo-SHI-TOMASI.ipynb
#  TakeshiHMM-Gazebo-SHOWDOC.ipynb
#  TakeshiHMM-GRAD_DESC-Copy1.ipynb
#  TakeshiHMM-ROBOT-NoiseODOM-Dim_reduction.ipynb
#  TakeshiHMM-ROBOT-ODOM_NOISE_CHARCTERIZATION.ipynb
#  TakeshiHMM-Robot-SHI-TOMASI.ipynb
#  trans.npy
#  trans_odom_correct.npy
#  trans_stat.npy
#  Untitled1.ipynb
#  Untitled2.ipynb
#  utils_hmm.py
#  utils_hmm.pyc
#  utils.pyc
#  vit_ckup.py
#  viterbi_takeshi_Pose_Gazebo.py
#  viterbi_takeshi.py
